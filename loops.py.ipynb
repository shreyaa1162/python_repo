# %%
num=input()
while num>=1:
  num//2
print(num)
# Out:
# 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1770/4215447916.py in <cell line: 0>()
#       1 num=input()
# ----> 2 while num>=1:
#       3   num//2
#       4 print(num)
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
n=16
base=2
log=0
while n >1:
  n//=base
  log+=1
  print(log)
# Out:
# 1
# 2
# 3
# 4

# %%
a=[1,2,3,4,5]
a.append(6)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a=[1,2,3,4,5]
a.append(6)
print(a)
