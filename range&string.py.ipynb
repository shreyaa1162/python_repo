# %%
a=[1,2,3,4,5]
popped_element=a.pop(4)
a.insert(0,popped_element)
print (a)
# Out:
# [5, 1, 2, 3, 4]

# %%
a=[4,2,3,1]
for i in range(len(a)-1):
  for j in range(1,len(a)-1):
    if a[i] > [j]:
      a[i],

      print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_993/101068343.py in <cell line: 0>()
#       2 for i in range(len(a)-1):
#       3   for j in range(1,len(a)-1):
# ----> 4     if a[i] > [j]:
#       5       a[i],
#       6
#
# TypeError: '>' not supported between instances of 'int' and 'list'

# %%
string="sandip"
string[0:3]
# Out:
# 'san'

# %%
string="sandip"
string[:]
# Out:
# 'sandip'

# %%
string="sandip"
string[::2]
# Out:
# 'sni'

# %%
a=10
b=5
print("a=",a,"b=",b)
print("a={} b={} a+b{}".format(a,b,a+b))
print(f"a={a} b={b} a+b{a+b}")
# Out:
# a= 10 b= 5
# a=10 b=5 a+b15
# a=10 b=5 a+b15

# %%
a=10
c=10
print(id(a),id(c))
b=5
print(id(c))
# Out:
# 11645640 11645640
# 11645640

# %%
s=input()
if s==s[::-1]:
  print("Palindrome")
else:
  print("Not Palindrome")
# Out:
# nayan
# Palindrome

# %%
string=input()
ascii=0
new_str=""
new_ascii=0
for i in string:
  ascii=ord(i)
  new_ascii=ascii-32
  new_chr=chr(new_ascii)
  new_str+=new_chr
print(new_str)
# Out:
# sandip
# SANDIP

# %%
+

# %%
string=input()
new_str=""
for i in string:
  new_str+=chr(ord(i)-32)
print(new_str)
# Out:
# sandip
# SANDIP
